# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
pip install mtcnn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
from mtcnn.mtcnn import MTCNN
from PIL import Image

detector = MTCNN(steps_threshold=[0.0, 0.0, 0.0])

def landmarks(img):
    faces = detector.detect_faces(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    face = max(faces, key=lambda x: x['confidence'])
    return face['keypoints']

def affineMatrix(lmks, scale=2.5):
    nose = np.array(lmks['nose'], dtype=np.float32)
    left_eye = np.array(lmks['left_eye'], dtype=np.float32)
    right_eye = np.array(lmks['right_eye'], dtype=np.float32)
    eye_width = right_eye - left_eye
    angle = np.arctan2(eye_width[1], eye_width[0])
    center = nose
    alpha = np.cos(angle)
    beta = np.sin(angle)
    w = np.sqrt(np.sum(eye_width**2)) * scale
    m = [[alpha, beta, -alpha * center[0] - beta * center[1] + w * 0.5],
        [-beta, alpha, beta * center[0] - alpha * center[1] + w * 0.5]]
    return np.array(m), (int(w), int(w))

if __name__ == '__main__':
  for i in range(4139,19291):
    INPUT_IMAGE = "C:/Users/VIPLAB/Desktop/Yan/Lee's Family Reunion/" +str(i) + '.jpg'
    OUTPUT_IMAGE = "C:/Users/VIPLAB/Desktop/Yan/Lee's Family Reunion face/"+str(i)+'.jpg'
    img = cv2.imread(INPUT_IMAGE)
    if img is None :
        print("无法加载图像文件。")
    
    mat, size = affineMatrix(landmarks(img))    
    cv2.imwrite(OUTPUT_IMAGE, cv2.warpAffine(img, mat, size))
    image = Image.open(OUTPUT_IMAGE)
    image = image.resize((160, 160))
    print(image.size)
    image.save(OUTPUT_IMAGE)
# Out:
# ...
# 881/881 [==============================] - 12s 14ms/step
# (160, 160)
# ...
# 881/881 [==============================] - 12s 13ms/step
# (160, 160)
# ...
# 884/884 [==============================] - 13s 14ms/step
# (160, 160)
# ...
# 896/896 [==============================] - 11s 13ms/step
# (160, 160)
# ...
# 883/883 [==============================] - 11s 13ms/step
# (160, 160)
# ...
# 882/882 [==============================] - 11s 13ms/step
# (160, 160)
# ...
# 884/884 [==============================] - 11s 13ms/step
# (160, 160)
# ...
# 882/882 [==============================] - 11s 13ms/step
# (160, 160)
# ...
# 898/898 [==============================] - 12s 13ms/step
# (160, 160)
# ...
# 882/882 [==============================] - 10s 11ms/step
# (160, 160)
# ...
# 880/880 [==============================] - 10s 12ms/step
# (160, 160)
# ...
# 880/880 [==============================] - 12s 13ms/step
# (160, 160)
# ...
# 881/881 [==============================] - 11s 13ms/step
# (160, 160)
# ...
# 881/881 [==============================] - 11s 13ms/step
# ...
